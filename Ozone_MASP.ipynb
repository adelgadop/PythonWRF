# %% [markdown]
# # Tropospheric Ozone Concentration in the MASP
# Project: **Simulation of Tropospheric Ozone Formation in the Metropolitan Region of São Paulo under Climate Change Scenarios**
#
# **University of São Paulo**
# ***
# Developed by Alejandro Delgado
#
# Type: Master's Dissertation
# ***

# %% [markdown]
# ## Downloading meteorological and air quality parameters from CETESB stations
#
# Parameters downloaded are:
# - Meteorological:
#   * temperature (tc)
#   * relative humidity (rh)
#   * solar radiation (sr)
#   * wind speed (ws)
#   * wind direction (wd)
# - Air quality:
#   * ozone (o3)
#   * nitrogen monoxide (no)
#   * nitrogen dioxide (no2)
#   * carbon monoxide (co)
#
# We import libraries to download information for all network stations located at the MASP

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# We read the file with station locations points

# %%
cetesb_stations = pd.read_csv(
    '3_Validation/cetesb_station_2017_codes_qualr.csv', encoding = "ISO-8859-1")
cetesb_stations[0:]
# Out:
#                  name        lat        lon  code
# 0           Americana -22.724253 -47.339549   290
# 1           Araçatuba -21.186841 -50.439317   107
# 2          Araraquara -21.782522 -48.185832   106
# 3               Bauru -22.326608 -49.092759   108
# 4             Cambuci -23.567708 -46.612273    90
# ..                ...        ...        ...   ...
# 63  S.Miguel Paulista -23.498526 -46.444803   236
# 64           Sorocaba -23.502427 -47.479030    67
# 65    Taboão da Serra -23.609324 -46.758294   103
# 66              Tatuí -23.360752 -47.870799   256
# 67            Taubaté -23.032351 -45.575805   280
#
# [68 rows x 4 columns]

# %%
cat 3_Validation/cetesb_station_2017_codes_qualr.csv
# Out:
# name,lat,lon,code
# Americana,-22.7242527,-47.33954929,290
# Ara�atuba,-21.1868411,-50.43931685,107
# Araraquara,-21.78252215,-48.18583181,106
# Bauru,-22.3266084,-49.09275931,108
# Cambuci,-23.56770841,-46.61227286,90
# Campinas-Centro,-22.9025248,-47.05721074,89
# Campinas-Taquaral,-22.87461894,-47.05897276,276
# Campinas-V.Uni�o,-22.94672842,-47.11928086,275
# Cap�o Redondo,-23.66835615,-46.78004338,269
# Carapicu�ba,-23.53139503,-46.83577973,263
# Catanduva,-21.14194276,-48.98307527,248
# Centro,-23.54780616,-46.6424145,94
# Cerqueira C�sar,-23.55354256,-46.67270477,91
# Cid.Universit�ria-USP-Ipen,-23.56634178,-46.73741428,95
# Congonhas,-23.61632008,-46.66346553,73
# Cubat�o-Centro,-23.87902673,-46.41848336,87
# Cubat�o-Vale do Mogi,-23.83158901,-46.36956879,119
# Cubat�o-V.Parisi,-23.84941617,-46.38867624,66
# Diadema,-23.68587641,-46.61162193,92
# Graja�-Parelheiros,-23.77626598,-46.69696108,98
# Guaratinguet�,-22.80191714,-45.19112236,289
# ...

# %%
import qualar_py as qr

# %%
obs_dates = pd.DataFrame({
    'date': pd.date_range('2016-01-01', periods=366/2*24, freq='H')
})
obs_dates['date_qualar']=obs_dates['date'].dt.strftime('%d/%m/%Y')
#print(obs_dates.head(),"\n", obs_dates.tail())
#obs_dates['date_local'] = obs_dates['date'].dt.tz_localize('UTC').dt.tz_convert('America/Sao_Paulo')
#obs_dates['date_qualar'] = obs_dates['date_local'].dt.strftime('%d/%m/%Y')
print(obs_dates.head(), "\n ... \n",obs_dates.tail())
# Out:
#                  date date_qualar
# 0 2016-01-01 00:00:00  01/01/2016
# 1 2016-01-01 01:00:00  01/01/2016
# 2 2016-01-01 02:00:00  01/01/2016
# 3 2016-01-01 03:00:00  01/01/2016
# 4 2016-01-01 04:00:00  01/01/2016
#  ...
#                      date date_qualar
# 4387 2016-07-01 19:00:00  01/07/2016
# 4388 2016-07-01 20:00:00  01/07/2016
# 4389 2016-07-01 21:00:00  01/07/2016
# 4390 2016-07-01 22:00:00  01/07/2016
# 4391 2016-07-01 23:00:00  01/07/2016

# %%
cetesb_login = 'user@example.com'
cetesb_password = 'xxxxx'
start_date = obs_dates.date_qualar.values[0]
end_date = obs_dates.date_qualar.values[-1]

# %%
for i in cetesb_stations.code:
    print('Downloading poll ' + cetesb_stations.name[cetesb_stations.code == i].values + ' Station')
    qr.all_photo(cetesb_login, cetesb_password,
                        start_date, end_date, i, csv_photo=True)
    print('Downloading meteo ' + cetesb_stations.name[cetesb_stations.code == i].values + ' Station')
    qr.all_met(cetesb_login, cetesb_password,
                        start_date, end_date, i, csv_met=True)
# Out:
# ['Downloading poll Americana Station']
# ['Downloading meteo Americana Station']
# ['Downloading poll Araçatuba Station']
# ['Downloading meteo Araçatuba Station']
# ['Downloading poll Araraquara Station']
# ['Downloading meteo Araraquara Station']
# ['Downloading poll Bauru Station']
# ['Downloading meteo Bauru Station']
# ['Downloading poll Cambuci Station']
# ['Downloading meteo Cambuci Station']
# ['Downloading poll Campinas-Centro Station']
# ['Downloading meteo Campinas-Centro Station']
# ['Downloading poll Campinas-Taquaral Station']
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# ~/opt/miniconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# ...
